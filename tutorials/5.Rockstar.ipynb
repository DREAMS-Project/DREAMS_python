# %%
# !pip install -e /home/aku7cf/DREAMS/DREAMS_python
# !pip install -e /path/to/DREAMS_python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///home/aku7cf/DREAMS/DREAMS_python
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for dreams_python (pyproject.toml) ... done
#   Created wheel for dreams_python: filename=dreams_python-0.1.0-0.editable-py3-none-any.whl size=4485 sha256=2329dd72f7fdf4d9f34224addd22e9c833365ac74be9f5fc30608a8cfca555c9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0czr_k4j/wheels/93/9c/36/d4c59b3fc31ec2b5dc143e4a986198ab2224d05d41a91e194c
# Successfully built dreams_python
# ...
#   Attempting uninstall: dreams_python
#     Found existing installation: dreams_python 0.1.0
#     Uninstalling dreams_python-0.1.0:
#       Successfully uninstalled dreams_python-0.1.0
# ...

# %%
import dreams_python

# %%
import numpy as np

# %%
mvs = dreams_python.DREAMS('/standard/DREAMS') ## default is mass varied suite (CDM/varied_mass/SB6/)

run  = 1 ## load simulation number 4
snap = 90 ## load snapshot 90 (z=0)

rockstar_cat = mvs.read_rockstar(run, snap, keys=['Mvir', 'ID'])
fof_cat = mvs.read_group_catalog(run, snap, keys=['GroupMass'])

h = mvs.get_h(run, snap)

params, header = mvs.read_param_file('TNG_SB6.txt')
target_masses = params[:, 0]

rockstar_id = mvs.get_target_rockstar_index(run, snap, target_masses[run])
fof_id = mvs.get_target_fof_index(run, snap, target_masses[run])

rockstar_mass = np.log10(rockstar_cat["Mvir"] / h)[rockstar_cat["ID"]==rockstar_id][0]
fof_mass = np.log10(fof_cat["GroupMass"][fof_id] * 1.00E+10/h)

print( f'Target Halo Mass   : {target_masses[run]:0.3f}' )
print( f'FoF Halo Mass      : {fof_mass:0.3f}' )
print( f'Rockstar Halo Mass : {rockstar_mass:0.3f}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 6
#       3 run  = 1 ## load simulation number 4
#       4 snap = 90 ## load snapshot 90 (z=0)
# ----> 6 rockstar_cat = mvs.read_rockstar(run, snap, keys=['Mvir', 'ID'])
#       7 fof_cat = mvs.read_group_catalog(run, snap, keys=['GroupMass'])
#       9 h = mvs.get_h(run, snap)
#
# File /sfs/gpfs/tardis/home/aku7cf/DREAMS/DREAMS_python/dreams_python/core.py:161, in DREAMS.read_rockstar(self, run, snap, keys, DMO)
#     159 def read_rockstar(self, run, snap, keys=[], DMO=False):
#     160     path = self.resolve_dir("Rockstar", run, snap, DMO)# / f"{self.box_or_run}_{run}" / f"out_{snap}.list"
# --> 161     self.check_path(path, 'Rockstar Catalog', run, snap)
#     163     output = dict()
#     164     with open(path, 'r') as f:
#
# ...
